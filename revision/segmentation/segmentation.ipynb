# %%
from tifffile import imread, imwrite
from skimage import filters, measure, feature, morphology, segmentation
import numpy as np
import sys, os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fpath = 'Z:/Data/Processed/2022-09-12-Rena-HeLa16Gene/output/2022-09-22-2D-max-projection'
areas = range(1,8)

# %% [markdown]
# ## 2D segmentation

# %%
# params
sigma = 6
nucleus_min_size = 100
nucleus_max_size = 40000

# %%
for im in areas:
    # nucleus
    dapi = imread(os.path.join(fpath, f'Area{im}_dapi_2d.tif'))
    dapi_gf = filters.gaussian(dapi, sigma=sigma)
    dapi_mf = filters.median(dapi_gf)
    thresh = filters.threshold_li(dapi_mf)
    binary = dapi_mf >= thresh
    nuclei = measure.label(binary)
    

    # # cytosol
    # flamingo = imread(os.path.join(fpath, f'Area{im}_flamingo_2d.tif'))
    break

# %% [markdown]
# ### test

# %%
dapi = imread(os.path.join(fpath, 'Area1_dapi_2d.tif'))
dapi_gf = filters.gaussian(dapi, sigma=6)
dapi_mf = filters.median(dapi_gf)
thresh = filters.threshold_li(dapi_mf)
binary = dapi_mf >= thresh

# %%
filters.try_all_threshold(dapi_mf[:3000,:3000], figsize=(30,30))

# %% [markdown]
# label connected components

# %%
nuclei = measure.label(binary)
example_large = nuclei[:3000,:3000][1900,500]
np.count_nonzero(nuclei==example_large)
# Out:
# 93846

# %%
# np.max(nuclei)
# for obj in range(1, np.max(nuclei)+1): # alt: regionprops
#     if np.count_nonzero(nuclei==obj) < nucleus_min_size or np.count_nonzero(nuclei==obj) > nucleus_max_size:
#         nuclei[nuclei==obj] = 0
# NOTE slower

# %%
nuclei = measure.label(binary)
rp = measure.regionprops(nuclei)
for obj in rp: # alt: regionprops
    if obj.area < 1000 or obj.area > 80000:
        nuclei[nuclei==obj.label] = 0

# %%
sns.histplot([r.area for r in rp])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
fig = plt.figure(figsize=(8,8))
# plt.imshow(dapi[:3000,:3000])
# plt.imshow(dapi_gf[:3000,:3000])
# plt.imshow(dapi_mf[:3000,:3000])
# plt.imshow(binary[:3000,:3000], cmap='gray')
plt.imshow(nuclei[:3000,:3000])
# plt.imshow(nuclei)

# %% [markdown]
# watershed

# %%
from scipy import ndimage
distance = ndimage.distance_transform_edt(binary)
local_max = feature.peak_local_max(distance, min_distance=20)
im_local_max = np.zeros(shape=binary.shape)
for lm in local_max:
    im_local_max[lm[0],lm[1]] = True
markers = measure.label(im_local_max)
label_ws = segmentation.watershed(-distance, markers, mask=binary)

# %%
# plt.imshow(distance[:2000,:2000])
# plt.imshow(im_local_max[:2000,:2000])
# plt.imshow(markers[:2000,:2000])
plt.imshow(label_ws[1000:3000,1000:3000])

# %%
rp = measure.regionprops(label_ws)
sns.histplot([r.area for r in rp])
len(rp)
# Out:
# 527

# %%
rp = measure.regionprops(label_ws)
for obj in rp: # alt: regionprops
    if obj.area < 1000 or obj.area > 80000:
        label_ws[label_ws==obj.label] = 0

# %%
np.unique(label_ws[1000:3000,1000:3000])
# Out:
# array([  0,  30,  35,  36,  38,  50,  53,  60,  64,  79,  80,  81,  82,
#         83,  96,  97, 113, 115, 122, 125])

# %%
fig, ax = plt.subplots(1,3,figsize=(12,3.5))
ax[0].imshow(dapi[1000:3000,1000:3000])
ax[1].imshow(label_ws[1000:3000,1000:3000])
ax[2].imshow(label_ws[1000:3000,1000:3000]==35)

# %% [markdown]
# random walker

# %%
markers[~binary] = -1
labels_rw = segmentation.random_walker(binary, markers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# z:\Connie\02.TEMPOmap\01.revision16Gene\code\segmentation\segmentation.ipynb Cell 20 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/z%3A/Connie/02.TEMPOmap/01.revision16Gene/code/segmentation/segmentation.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> markers[~binary] = -1
# ----> <a href='vscode-notebook-cell:/z%3A/Connie/02.TEMPOmap/01.revision16Gene/code/segmentation/segmentation.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> labels_rw = segmentation.random_walker(binary, markers)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\skimage\_shared\utils.py:394, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     391 channel_axis = kwargs.get('channel_axis', None)
#     393 if channel_axis is None:
# --> 394     return func(*args, **kwargs)
#     396 # TODO: convert scalars to a tuple in anticipation of eventually
#     397 #       supporting a tuple of channel axes. Right now, only an
#     398 #       integer or a single-element tuple is supported, though.
#     399 if np.isscalar(channel_axis):
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\skimage\_shared\utils.py:348, in deprecate_multichannel_kwarg.__call__.<locals>.fixed_func(*args, **kwargs)
#     345     kwargs['channel_axis'] = convert[kwargs.pop('multichannel')]
#     347 # Call the function with the fixed arguments
# --> 348 return func(*args, **kwargs)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\skimage\segmentation\random_walker_segmentation.py:496, in random_walker(data, labels, beta, mode, tol, copy, multichannel, return_full_prob, spacing, prob_tol, channel_axis)
#     490 lap_sparse, B = _build_linear_system(data, spacing, labels, nlabels, mask,
#     491                                      beta, multichannel)
#     493 # Solve the linear system lap_sparse X = B
#     494 # where X[i, j] is the probability that a marker of label i arrives
#     495 # first at pixel j by anisotropic diffusion.
# --> 496 X = _solve_linear_system(lap_sparse, B, tol, mode)
#     498 if X.min() < -prob_tol or X.max() > 1 + prob_tol:
#     499     warn('The probability range is outside [0, 1] given the tolerance '
#     500          '`prob_tol`. Consider decreasing `beta` and/or decreasing '
#     501          '`tol`.')
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\skimage\segmentation\random_walker_segmentation.py:194, in _solve_linear_system(lap_sparse, B, tol, mode)
#     192     M = ml.aspreconditioner(cycle='V')
#     193     maxiter = 30
# --> 194 cg_out = [
#     195     cg(lap_sparse, B[:, i].toarray(),
#     196        tol=tol, atol=0, M=M, maxiter=maxiter)
#     197     for i in range(B.shape[1])]
#     198 if np.any([info > 0 for _, info in cg_out]):
#     199     warn("Conjugate gradient convergence to tolerance not achieved. "
#     200          "Consider decreasing beta to improve system conditionning.",
#     201          stacklevel=2)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\skimage\segmentation\random_walker_segmentation.py:195, in <listcomp>(.0)
#     192     M = ml.aspreconditioner(cycle='V')
#     193     maxiter = 30
#     194 cg_out = [
# --> 195     cg(lap_sparse, B[:, i].toarray(),
#     196        tol=tol, atol=0, M=M, maxiter=maxiter)
#     197     for i in range(B.shape[1])]
#     198 if np.any([info > 0 for _, info in cg_out]):
#     199     warn("Conjugate gradient convergence to tolerance not achieved. "
#     200          "Consider decreasing beta to improve system conditionning.",
#     201          stacklevel=2)
#
# File <decorator-gen-7>:2, in cg(A, b, x0, tol, maxiter, M, callback, atol)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\_lib\_threadsafety.py:44, in ReentrancyLock.decorate.<locals>.caller(func, *a, **kw)
#      42 def caller(func, *a, **kw):
#      43     with self:
# ---> 44         return func(*a, **kw)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\sparse\linalg\_isolve\iterative.py:329, in cg(A, b, x0, tol, maxiter, M, callback, atol)
#     327 elif (ijob == 1):
#     328     work[slice2] *= sclr2
# --> 329     work[slice2] += sclr1*matvec(work[slice1])
#     330 elif (ijob == 2):
#     331     work[slice1] = psolve(work[slice2])
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\sparse\linalg\_interface.py:232, in LinearOperator.matvec(self, x)
#     229 if x.shape != (N,) and x.shape != (N,1):
#     230     raise ValueError('dimension mismatch')
# --> 232 y = self._matvec(x)
#     234 if isinstance(x, np.matrix):
#     235     y = asmatrix(y)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\sparse\linalg\_interface.py:199, in LinearOperator._matvec(self, x)
#     189 def _matvec(self, x):
#     190     """Default matrix-vector multiplication handler.
#     191
#     192     If self is a linear operator of shape (M, N), then this method will
#    (...)
#     197     will define matrix-vector multiplication as well.
#     198     """
# --> 199     return self.matmat(x.reshape(-1, 1))
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\sparse\linalg\_interface.py:337, in LinearOperator.matmat(self, X)
#     333 if X.shape[0] != self.shape[1]:
#     334     raise ValueError('dimension mismatch: %r, %r'
#     335                      % (self.shape, X.shape))
# --> 337 Y = self._matmat(X)
#     339 if isinstance(Y, np.matrix):
#     340     Y = asmatrix(Y)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\sparse\linalg\_interface.py:731, in MatrixLinearOperator._matmat(self, X)
#     730 def _matmat(self, X):
# --> 731     return self.A.dot(X)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\sparse\_base.py:413, in spmatrix.dot(self, other)
#     400 def dot(self, other):
#     401     """Ordinary dot product
#     402
#     403     Examples
#    (...)
#     411
#     412     """
# --> 413     return self @ other
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\sparse\_base.py:620, in spmatrix.__matmul__(self, other)
#     617 if isscalarlike(other):
#     618     raise ValueError("Scalar operands are not allowed, "
#     619                      "use '*' instead")
# --> 620 return self._mul_dispatch(other)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\sparse\_base.py:523, in spmatrix._mul_dispatch(self, other)
#     521     return self._mul_vector(other)
#     522 elif other.shape == (N, 1):
# --> 523     return self._mul_vector(other.ravel()).reshape(M, 1)
#     524 elif other.ndim == 2 and other.shape[0] == N:
#     525     return self._mul_multivector(other)
#
# File c:\Users\wangk\.conda\envs\connie\lib\site-packages\scipy\sparse\_compressed.py:489, in _cs_matrix._mul_vector(self, other)
#     487 # csr_matvec or csc_matvec
#     488 fn = getattr(_sparsetools, self.format + '_matvec')
# --> 489 fn(M, N, self.indptr, self.indices, self.data, other, result)
#     491 return result
#
# KeyboardInterrupt:

# %%
# save a section for CellProfiler testing
dapi = imread(os.path.join(fpath, 'Area1_dapi_2d.tif'))
flamingo = imread(os.path.join(fpath, 'Area1_flamingo_2d.tif'))
dapi_test = dapi[:5000, :5000]
flamingo_test = flamingo[:5000, :5000]
imwrite(os.path.join(fpath, 'dapi_test.tif'), dapi_test)
imwrite(os.path.join(fpath, 'flamingo_test.tif'), flamingo_test)
